# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/karan/Downloads/headbrain.csv")

# %%
print(df.shape)
# Out:
# (237, 4)

# %%
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = df['Head Size(cm^3)'].values
Y = df['Brain Weight(grams)'].values

# %%
#mean of x and y
mean_x = np.mean(X)
mean_y = np.mean(Y)

#total no of values
m = len(X)

#using the formula to calculate b1 and b0
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] -mean_x) **2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)
    
    
print(b1, b0)
# Out:
# 0.26342933948939945 325.57342104944223

# %%
#plotting the valus on regreesion line
max_x = np.max(X) 
min_x = np.min(X) 

#calculating the line values x and y
x = np.linspace(min_x, max_x)
y = b0 + b1 * x

#plotting the line
plt.plot(x, y, color='#58b970', label='Regression line')
#ploting the  scatter points
plt.scatter(X, Y, c='#ef5423', label='scatter plot')

plt.xlabel('Head Size(cm^3)')
plt.ylabel('Brain Weight(grams')
plt.legend()
plt.show()

# %%
ss_t = 0
ss_r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    ss_t += (Y[i] - mean_y) ** 2
    ss_r += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# 0.6393117199570003
